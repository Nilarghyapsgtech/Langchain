# %%
import os

if os.getenv('LLAMA_CLOUD_API_KEY'):
    print("API_KEY Present")
else:
    print("API_KEY not Present")
# Out:
# API_KEY Present

# %%
from llama_cloud_services import LlamaParse
import os
import json
from pathlib import Path
from typing import List,Dict
import nest_asyncio
nest_asyncio.apply()
from dotenv import load_dotenv

load_dotenv()

from importlib.metadata import version
print(version('llama_cloud_services'))
# Out:
# 0.6.54

# %%
parser=LlamaParse(
    result_type="markdown"
)

config_categories= {
    "Authentication":["base_url","api_key"],
    "Output Control":["result_type","language","split_by_page"],
    "Mode Selection": ["fast_mode","premium_mode","auto_mode","preset"],
    "OCR & Images": ["disable_ocr", "high_res_ocr", "extract_charts", "take_screenshot"],
    "Layout": ["extract_layout", "do_not_unroll_columns"],
    "Structured Output": ["structured_output", "structured_output_json_schema"],
    "Prompts": ["parsing_instruction", "system_prompt", "formatting_instruction"],
    "Performance": ["num_workers", "job_timeout_in_seconds", "verbose"],
}

for category,params in config_categories.items():
    print(f"\n{category}")
    for param in params:
        print(f"- {param}")
# Out:
# Authentication
# - base_url
# - api_key
#
# Output Control
# - result_type
# - language
# - split_by_page
#
# Mode Selection
# - fast_mode
# - premium_mode
# - auto_mode
# - preset
#
# OCR & Images
# - disable_ocr
# - high_res_ocr
# - extract_charts
# - take_screenshot
#
# Layout
# - extract_layout
# - do_not_unroll_columns
#
# Structured Output
# - structured_output
# - structured_output_json_schema
#
# Prompts
# - parsing_instruction
# - system_prompt
# - formatting_instruction
#
# Performance
# - num_workers
# - job_timeout_in_seconds
# - verbose

# %% [markdown]
# Comaring Markdown vs Text

# %%
file_src='SRCs'
file=list(Path(file_src).glob('*.pdf'))[1]
print(file)

parser_markdown=LlamaParse(
    result_type="markdown",
    verbose=True
)

parser_text=LlamaParse(
    result_type="text",
    verbose=True
)
for i in range(2):
    print('*'*50)
    if i==0:
        docs=parser_markdown.load_data(file)
        print(docs)
    else:
         docs=parser_text.load_data(file)
         print(docs)
    print('*'*50)
# Out:
# SRCs/AIAN.pdf
# **************************************************
# Started parsing the file under job_id 099bc5d3-b5e5-4779-9a45-1b47f8945b0c
# ...

# %% [markdown]
# Async

# %%
docs_parser=LlamaParse(
    result_type="text",
    verbose=True

)

docs=await docs_parser.aload_data(file)
print(docs)
# Out:
# Started parsing the file under job_id 3bba0b44-9c29-4192-bf4e-aa8531851559
#     arXiv:1706.03762v7 [cs.CL] 2 Aug 2023
#
#   Provided proper attribution is provided, Google hereby grants permission to
# reproduce the tables and figures in this paper solely for use in journalistic or
#     scholarly works.
#
#     Attention Is All You Need
#
#     Ashish Vaswani∗  Noam Shazeer∗        Niki Parmar∗  Jakob Uszkoreit∗
#     Google Brain         Google Brain     Google Research    Google Research
# avaswani@google.com    noam@google.com    nikip@google.com    usz@google.com
#
#     Llion Jones∗     Aidan N. Gomez∗ †         Łukasz Kaiser∗
# Google Research    University of Toronto          Google Brain
# llion@google.com    aidan@cs.toronto.edu    lukaszkaiser@google.com
#
#                      Illia Polosukhin∗ ‡
#                      illia.polosukhin@gmail.com
#
#                                                           Abstract
#
# ...

# %% [markdown]
# Individual Pages

# %%
parser=LlamaParse(
    result_type='markdown',
    verbose=True
)

if Path(file).exists():
    job=parser.parse(file)

for items in job.pages[:3]:
    print(items.text)
# Out:
# Started parsing the file under job_id 4c48b1f5-6893-4a86-91a4-3551303233ec
# ...

# %% [markdown]
# Split by page

# %%
from llama_cloud_services import LlamaParse

parser=LlamaParse(
    result_type="markdown",
    split_by_page=True,
    verbose=True
)

docs=parser.load_data(file)

print(docs[0].text)
# Out:
# Started parsing the file under job_id f96a398d-7a2e-4ccf-8557-b9aecc649dc1
# arXiv:1706.03762v7 [cs.CL] 2 Aug 2023
#
# # Attention Is All You Need
#
# Ashish Vaswani∗  Noam Shazeer∗        Niki Parmar∗  Jakob Uszkoreit∗
#
# Google Brain         Google Brain     Google Research    Google Research
#
# avaswani@google.com    noam@google.com    nikip@google.com    usz@google.com
#
# Llion Jones∗     Aidan N. Gomez∗ †         Łukasz Kaiser∗
#
# Google Research    University of Toronto          Google Brain
#
# llion@google.com    aidan@cs.toronto.edu    lukaszkaiser@google.com
#
# Illia Polosukhin∗ ‡
#
# illia.polosukhin@gmail.com
#
# # Abstract
#
# ...

# %% [markdown]
# Page Formatting

# %%
parser=LlamaParse(
    result_type="markdown",
    verbose=False,
    page_prefix="[Page Start]",
    page_suffix="[Page End]",
    page_separator="\n\n--------PAGE BREAK------------\n\n"
)

docs=parser.load_data(file)
print(docs[0].text)

# %% [markdown]
# Presets

# %% [markdown]
# Fast Preset

# %%
import time

parser=LlamaParse(
    result_type="text",
    verbose=True,
    preset="fast"
)

start=time.time()
docs=parser.load_data(file)
timeTaken=time.time()-start

print(timeTaken)
print(len(docs[0].text))
# Out:
# Started parsing the file under job_id 90d778bd-b70c-47e0-9802-f25b3729414b
# 9.595510005950928
# 15

# %% [markdown]
# Premium Preset

# %%
parser=LlamaParse(
    result_type="markdown",
    verbose=True,
    preset="premium"
)

start=time.time()
docs=parser.load_data(file)
end=time.time()-start

print(end)
print(len(docs[0].text))
# Out:
# Started parsing the file under job_id 43816155-e161-45ce-9468-e8c081b737ac
# 48.24288010597229
# 3033

# %% [markdown]
# Parser Mode

# %% [markdown]
# fast,premium

# %%
from llama_cloud_services import LlamaParse
import time

fast_parser=LlamaParse(
    result_type="markdown",
    verbose=True,
    fast_mode=True

)

premium_parser=LlamaParse(
    result_type="markdown",
    verbose=True,
    premium_mode=True
)

start=time.time()
docs=fast_parser.load_data(file)
end=time.time()-start

print('*'*60)
print(end)
print('*'*60)

start=time.time()
docs=premium_parser.load_data(file)
end=time.time()-start

print('*'*60)
print(end)
print('*'*60)
# Out:
# Started parsing the file under job_id c28b5a3e-cefa-47c9-b85f-ef6b5111c853
# Error while parsing the file '<bytes/buffer>': 'markdown'
# ************************************************************
# 12.813760042190552
# ************************************************************
# Started parsing the file under job_id 888cea2d-1b92-4732-a930-1cb479c5d9e9
# ************************************************************
# 40.463284969329834
# ************************************************************

# %% [markdown]
# Auto Mode

# %%
from llama_cloud_services import LlamaParse
parser=LlamaParse(
    auto_mode=True,
    verbose=True,
    auto_mode_trigger_on_image_in_page=True,
    auto_mode_trigger_on_table_in_page=True,
    result_type='text'
)

# %% [markdown]
# Auto Mode with Json Config.  (Did not work)

# %%
from llama_cloud_services import LlamaParse
import json
config={
    "trigger_conditions":{
        "on_image": True,
        "on_table": True,
        "on_text_patterns": ["figure","table","chart"]
    },
    "fallback_mode": "fast",
    "upgrade_mode": "premium"
}

parser=LlamaParse(
    result_type="markdown",
    verbose=True,
    auto_mode=True,
    auto_mode_configuration_json=json.dumps(config),
    
    
)

docs=parser.load_data(file)

print(docs)
# Out:
# Started parsing the file under job_id b8288dfa-c93b-4154-8963-fcab5d29a202
# Error while parsing the file '<bytes/buffer>': Job ID: b8288dfa-c93b-4154-8963-fcab5d29a202 failed with status: ERROR, Error code: INVALID_AUTO_MODE_CONFIGURATION, Error message: Invalid auto_mode_configuration_json, should be an array
# []

# %% [markdown]
# Granular Parsing Mode

# %%
from llama_cloud_services import LlamaParse

parser=LlamaParse(
    result_type="markdown",
    parse_mode="parse_page_with_llm",

)

docs=parser.load_data(file)

print(docs[0].text)
# Out:
# Started parsing the file under job_id 3727c26f-e7af-4e3d-b66a-d7fce3c59eee
# ...

# %% [markdown]
# Parsing with OCR

# %%
from llama_cloud_services import LlamaParse

parser=LlamaParse(
    result_type="markdown",
    high_res_ocr=True,
    verbose=True
)
file=list(Path('SRCs').glob('*.pdf'))[0]
docs=parser.load_data(file)

print(docs[0].text)
# Out:
# Started parsing the file under job_id 55fac679-d03e-4c39-a7a7-d6810e3d8872
#
# Unstructured universal entry
#
# # 1. The partition () function
#
# is the point for document processing. Unstructured automatically detects partitioning logic.
#
# # 2. Narrative Text
#
# Tabular data
#
# | Table- | asuiar ate Cuilter, |
# | ------ | ------------------- |
#
# # 3. List Item
#
# numbered)
#
# # 4. Image
#
# Embedded images.
#
# # 5. Header
#
# Page footers
#
# # 6. Footer
#
# Page content elements
#
# # 7. Text
#
# Generic

# %% [markdown]
# HTML parsing

# %%
from llama_cloud_services import LlamaParse

parser=LlamaParse(
    result_type="markdown",
    verbose=True
)
file=list(Path('SRCs').glob('*.html'))[0]
docs=parser.load_data(file)

print(docs[0].text)
# Out:
# Started parsing the file under job_id 050c736f-6721-4fed-a808-80a5f1036c82
# # This is Heading 1 (Main Title)
#
# Usually used for the main title of the page.
#
# # This is Heading 2 (Section Title)
#
# Used for major sections.
#
# # This is Heading 3 (Sub-section)
#
# Used for subsections under h2.
#
# # This is Heading 4
#
# Less important than h3.
#
# # This is Heading 5
#
# Rarely used, but still valid.
#
# # This is Heading 6
#
# Smallest and least important heading.

# %% [markdown]
# Word Docs

# %%
parse=LlamaParse(
    result_type="markdown",
    verbose=True,
    spreadsheet_extract_sub_tables=True,
    compact_markdown_table=True,
    guess_xlsx_sheet_names=True,
    output_tables_as_HTML=True
)

file=list(Path('SRCs').glob('*.xlsx'))[0]

docs=parser.load_data(file)
print(docs)
# Out:
# Started parsing the file under job_id 6e830757-2f1f-4ec5-925d-a22ade4b6b28
# ...

# %% [markdown]
# Parsing Multiple Files

# %%
exts=['*.pdf','*.html']
files=[]
for ext in exts:
    files.append(list(Path('SRCs').glob(ext))[0])



parser=LlamaParse(
    result_type="markdown",
    verbose=True,
    num_workers=4
)
docs=parser.load_data(files)


print(docs)
# Out:
# Parsing files:   0%|          | 0/2 [00:00<?, ?it/s]
# Started parsing the file under job_id bcfee871-40f1-4814-8f27-619c2fe9c4b1
# Parsing files:  50%|█████     | 1/2 [00:06<00:06,  6.96s/it]
# Started parsing the file under job_id 0a71bf72-324e-42f2-8701-a121eee6e644
# Parsing files: 100%|██████████| 2/2 [00:32<00:00, 16.07s/it]
# ...

# %% [markdown]
# Charts

# %%
from llama_cloud_services import LlamaParse

parse=LlamaParse(
    result_type="markdown",
    extract_charts=True,
    verbose=True
)

docs=parser.load_data(files)
print(docs)

# %% [markdown]
# ScreenShots

# %%
from llama_cloud_services import LlamaParse

parser=LlamaParse(
    result_type="markdown",
    verbose=True,
    take_screenshot=True
)

docs=parser.load_data(docs)

# %% [markdown]
# Using 3rd party multimodal models

# %%
from llama_cloud_services import LlamaParse
from pathlib import Path
files=list(Path('SRCs').glob('*.pdf'))[0]

parser=LlamaParse(
    result_type="markdown",
    use_vendor_multimodal_model=True,
    vendor_multimodal_model_name='openai-gpt4o',
    verbose=True
)

docs=parser.load_data(files)
print(docs)
# Out:
# Started parsing the file under job_id 2f11dbdc-e5f5-4e4c-a177-36b86e678356
# ...

# %% [markdown]
# Layout Extraction

# %%
from llama_cloud_services import LlamaParse

parser=LlamaParse(
    result_type="markdown",
    extract_layout=True,
    verbose=True,
)
files=list(Path('SRCs').glob('*.pdf'))[0]
job_results=parser.parse([files])

if job_results:
    result=job_results[0]

for i,page in enumerate(result.pages[:3]):
    if i==0:
        print('*'*60)
        print(page)
        print('*'*60)
    if hasattr(page,'layout') and page.layout:
        print(type(page.layout).__name__)
    if isinstance(page.layout,dict):
        print(list(page.layout.keys())[:5])
# Out:
# Getting job results:   0%|          | 0/1 [00:00<?, ?it/s]
# Started parsing the file under job_id bc434268-0450-4d44-9f0c-edd090682305
# Getting job results: 100%|██████████| 1/1 [00:07<00:00,  7.92s/it]
# ************************************************************
# ...

# %% [markdown]
# Preserve column Layout

# %%
from llama_cloud_services import LlamaParse

parser=LlamaParse(
    result_type="markdown",
    verbose=True,
    extract_layout=True,
    do_not_unroll_columns=True
)


job=parser.parse([files])
if job:
    result=job[0]

for i,pages in enumerate(result.pages[:3]):
    if hasattr(pages,'layout'):
        print(type(page.layout).__name__)
    if isinstance(page.layout,dict):
        print(list(page.layout.keys())[:5])

# %% [markdown]
# Bounding Box

# %%
parser_bbox = LlamaParse(
    result_type="markdown",
    bbox_top=0.1,      # Start 10% from top
    bbox_bottom=0.9,   # End at 90% from top (10% margin at bottom)
    bbox_left=0.05,    # Start 5% from left
    bbox_right=0.95,   # End at 95% from left (5% margin at right)
    verbose=True,
)

print("BOUNDING BOX EXTRACTION")
print("=" * 50)
print("Configuration (percentages of page):")
print("  - bbox_top: 0.1 (10% from top)")
print("  - bbox_bottom: 0.9 (90% from top)")
print("  - bbox_left: 0.05 (5% from left)")
print("  - bbox_right: 0.95 (95% from left)")
print("\nUse cases:")
print("  - Skip headers and footers")
print("  - Extract specific page regions")
print("  - Ignore page margins")
print("\nExample - Extract only main content:")
print("  parser = LlamaParse(")
print("      bbox_top=0.15,    # Skip header")
print("      bbox_bottom=0.85, # Skip footer")
print("  )")
